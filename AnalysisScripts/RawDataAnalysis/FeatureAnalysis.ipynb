# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("../Data/Combined/0.2.2-hasTemperature.csv")

# %%
df2 = df.dropna(subset=["HenryConstant"])
hL = df2["HenryConstant"].values
filteredHL = hL[hL < 1e+10]
print(len(hL))
print(len(filteredHL))
# plt.hist(hL, bins=100)
plt.hist(np.log10(hL), bins=100)
plt.show()
# Out:
# 7642
# 7465

# %%
# plt.hist(filteredHL, bins=100)
plt.hist(np.log10(filteredHL), bins=100)
plt.show()
